# %% [markdown]
# <a href="https://colab.research.google.com/github/misun0314/AI-Python/blob/main/0529%EA%B0%95%EC%9D%98%EC%95%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 바이브 코딩을 활용한 데이터 분석 및 시각화-6차시(5.29)
# ## 데이터시각화 모듈
#
#
# ---
# ### 🎯 이번 차시 학습 내용
#
# - 파이썬의 데이터 시각화 패키지(matplotlib, seaborn) 이해
# - Matplotlib의 기본 흐름(그리기 → 라벨링 → 표시)을 이해
# - seaborn 의 기본 사용법 이해
# - Pandas 데이터로 간단한 시각화 수행
# - LLM을 활용해 차트 선택/디버깅/해석 연습

# %% [markdown]
# ##구글 드라이브 마운트
# 로컬에 있는 파일을 구글 드라이브에 업로드한 후 사용하기 위함

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Step 0. 실행 환경 준비(Colab/Jupyter)
#
# ### 설치 확인과 한글 처리 준비
#  `matplotlib / pandas / numpy` 버전이 출력된다.

# %% [markdown]
# 한글 나눔 폰트 설치

# %%
# !apt-get update -qq
# !apt-get install -y fonts-nanum* -qq

# %% [markdown]
# * 새로 설치된 폰트 인식

# %%
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# * 런타임-> 세션 다시 시작
# * 현재 작업 디렉터리 연결

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/미래혁신인재양성과정/')

# %%
# !ls

# %% [markdown]
# * 필수 라이브러리 로드

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

print('python', sys.version.split()[0])
print('numpy', np.__version__)
print('pandas', pd.__version__)
print('matplotlib', mpl.__version__)
print('seaborn', sns.__version__)

mpl.rcParams['axes.unicode_minus'] = False # - 기호 깨짐 방지

# %% [markdown]
# * 기본 폰트로 한글 폰트 전역 설정

# %%
fontpath="/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
font=fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# * 그래프 한글 설정 확인을 위한 파일 데이터 로드

# %%
df_cc = pd.read_csv("projectlab/2014-2024_사이버범죄 발생건수와 검거건수.csv", encoding="cp949")
df_cc

# %% [markdown]
# * 그래프 한글 설정 확인을 위한 그래프 플롯 후 파일 저장

# %%
df_cc.plot(kind="line", x="년도", y="검거율")
plt.title("2014-2024년 사이버범죄 검거율 추이")
plt.savefig("projectlab/2014-2024_사이버범죄검거율_추이_시계열.png")  # 구글드라이브에 저장
plt.show()
plt.close()

# %% [markdown]
# * 구글드라이브의 파일 PC로 다운로드

# %%
from google.colab import files
files.download("projectlab/2014-2024_사이버범죄검거율_추이_시계열.png")  # colab에서 추가

# %% [markdown]
# ## Step 1. Matplotlib 기본 패턴(최소 코드)
#
# ### 해야 할 것
# - import → 데이터 준비
# - `plt.plot()`으로 그리기
# - `title/xlabel/ylabel` 넣고 `show()`
#
# ### 체크
# - 선그래프 1개가 뜨고 제목/축 라벨이 보인다.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y)
plt.title('Line Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Step 2. 선그래프(Line) — 시간에 따른 변화
#
# ### 해야 할 것
# - x축=시간(또는 순서), y축=값
# - `marker='o'`로 점 확인
# - `grid(True)`로 격자 표시
#
# ### 체크
# - 요일별 걸음 수 추세를 선으로 읽을 수 있다.

# %%
import matplotlib.pyplot as plt

days = ['Mon','Tue','Wed','Thu','Fri']
steps = [5200, 7400, 6800, 9100, 8000]

plt.plot(days, steps, marker='o')
plt.title('Daily Steps')
plt.xlabel('Day')
plt.ylabel('Steps')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step 3. 막대그래프(Bar) — 범주 비교
#
# ### 해야 할 것
# - `labels=범주`, `values=값`
# - label이 길면 회전(rotation) 고려
#
# ### 체크
# - A/B/C 막대가 나타나고 B가 가장 크다.

# %%
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C']
values = [5, 8, 3]

plt.bar(labels, values)
plt.title('Bar Chart')
plt.xlabel('Group')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## Step 4. 히스토그램(Histogram) — 분포 보기
#
# ### 해야 할 것
# - `data`는 숫자 리스트/배열
# - `bins`로 구간 수 조절
#
# ### 체크
# - 연속 구간 막대가 나오며 분포 모양을 관찰할 수 있다.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)  # (선택) 실행할 때마다 비슷한 결과를 보고 싶다면
data = np.random.randn(1000)

plt.hist(data, bins=20)
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Step 5. 산점도(Scatter) — 두 변수 관계
#
# ### 해야 할 것
# - x=변수1, y=변수2
# - 점의 퍼짐을 보고 관계/이상치(outlier)를 관찰
#
# ### 체크
# - 점들이 찍히고 관계를 추측할 수 있다.

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,1,5,3]

plt.scatter(x, y)
plt.title('Scatter')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step 6. 여러 선 + 범례(legend)
#
# ### 해야 할 것
# - 각 선에 `label` 지정
# - `plt.legend()`로 범례 표시
#
# ### 체크
# - A/B 두 선이 보이고 범례에 A, B가 표시된다.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
a = [10, 20, 15]
b = [8, 18, 25]

plt.plot(x, a, label='A')
plt.plot(x, b, label='B')
plt.title('Two Lines')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 7. 그래프 저장(`savefig`) — `show()`보다 먼저
#
# ### 해야 할 것
# - 파일명(경로 포함) 정하기
# - `plt.savefig()`는 `plt.show()`보다 먼저 호출
#
# ### 체크
# - 현재 폴더에 `figure.png`가 생긴다.

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3], [2,3,5])
plt.title('Save Example')
plt.xlabel('x')
plt.ylabel('y')

plt.savefig('projectlab/figure.png')
plt.show()

print('saved: figure.png')

# %% [markdown]
# ## Step 8. Pandas로 빠르게 그리기(`plot kind`)
#
# ### 해야 할 것
# - DataFrame 생성(또는 CSV 읽기)
# - `df[col].plot(kind=...)`
#
# ### 체크
# - score 분포 히스토그램이 뜨고, `bins=5`라 구간이 5개로 보인다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'score':[70,85,90,60,75,88,95]})
# df = pd.read_csv('data.csv')

df['score'].plot(kind='hist', bins=5)
plt.title('Score Distribution')
plt.xlabel('score')
plt.show()

# %% [markdown]
# ### Pandas `plot(kind=...)`의 다른 그래프 종류
#
# `df.plot()` 메서드는 `kind` 파라미터를 통해 다양한 종류의 그래프를 쉽게 그릴 수 있습니다. `kind`에 지정할 수 있는 주요 값들은 다음과 같습니다:
#
# *   `'line'` (기본값): 선 그래프
# *   `'bar'`: 막대 그래프 (수직)
# *   `'barh'`: 수평 막대 그래프
# *   `'hist'`: 히스토그램
# *   `'box'`: 박스 플롯
# *   `'kde'` 또는 `'density'`: 커널 밀도 추정 플롯
# *   `'area'`: 영역 플롯
# *   `'pie'`: 파이 차트
# *   `'scatter'`: 산점도 (x, y 인자 필요)
# *   `'hexbin'`: 헥스빈 플롯 (x, y 인자 필요)
#
# 여기 몇 가지 예시를 들어보겠습니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 예시 데이터프레임 생성
data = {
    'category': ['A', 'B', 'C', 'D', 'E'],
    'value1': [10, 25, 15, 30, 20],
    'value2': [12, 20, 18, 25, 22],
    'x_data': [1, 2, 3, 4, 5],
    'y_data': [2, 4, 1, 5, 3]
}
df_plot_examples = pd.DataFrame(data)
df_plot_examples['date'] = pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'])
df_plot_examples = df_plot_examples.set_index('date')

print("예시 데이터프레임:")
display(df_plot_examples)

# %% [markdown]
# #### 1. 선 그래프 (`kind='line'`)

# %%
# 'value1' 컬럼의 선 그래프
df_plot_examples['value1'].plot(kind='line', marker='o')
plt.title('Line Plot of Value1 over Time')
plt.xlabel('Date')
plt.ylabel('Value1')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2. 막대 그래프 (`kind='bar'`)

# %%
# 'category'를 인덱스로, 'value1'을 값으로 하는 막대 그래프
df_plot_examples.set_index('category')['value1'].plot(kind='bar', color='skyblue')
plt.title('Bar Plot of Value1 by Category')
plt.xlabel('Category')
plt.ylabel('Value1')
plt.xticks(rotation=0) # x축 레이블 회전 방지
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### 3. 산점도 (`kind='scatter'`)

# %%
# 'x_data'와 'y_data' 컬럼을 이용한 산점도
df_plot_examples.plot(kind='scatter', x='x_data', y='y_data', title='Scatter Plot of X vs Y', color='red')
plt.xlabel('X Data')
plt.ylabel('Y Data')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 4. 박스 플롯 (`kind='box'`)

# %%
# 'value1'과 'value2' 컬럼의 박스 플롯 (분포, 이상치 확인)
df_plot_examples[['value1', 'value2']].plot(kind='box', title='Box Plot of Value1 and Value2')
plt.ylabel('Values')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## 실습: CSV로 그래프 2개 + 해석 2줄
#
# ### 체크리스트
# - CSV 1개 선택(수업 제공/개인 데이터)
# - 그래프 2종류 이상(선+히스토그램 등)
# - 각 그래프에 제목/축 라벨 포함
# - 그래프에서 읽은 결론 2줄 작성
# - 가능하면 `savefig`로 1개 저장
#
# 아래는 **연습용 CSV를 생성**해서 실습하는 예시입니다.

# %%
import pandas as pd

# (예시) 간단한 CSV 데이터 생성
data = {
    'date': pd.date_range('2026-01-01', periods=7, freq='D'),
    'study_time': [1, 2, 2.5, 3, 1.5, 4, 3.5],
    'score': [60, 65, 70, 75, 68, 85, 80]
}
df = pd.DataFrame(data)
df.to_csv('week11_sample.csv', index=False)
df

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('week11_sample.csv')

# 그래프 1) 날짜별 점수(선그래프)
plt.plot(df['date'], df['score'], marker='o')
plt.title('Score by Date')
plt.xlabel('date')
plt.ylabel('score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 그래프 2) 점수 분포(히스토그램)
plt.hist(df['score'], bins=5)
plt.title('Score Distribution')
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## 차트 선택 가이드
#
# - 추세(시간 변화): 선그래프
# - 범주 비교: 막대그래프
# - 분포 확인: 히스토그램
# - 관계/상관: 산점도
#
# Tip: **질문을 먼저 정하면 차트가 따라온다**

# %% [markdown]
# ### 해당 파일을 사용하여 그래프 만들어보기

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('projectlab/sample_data.csv')

# %% [markdown]
# ## With AI 1: 차트 선택 프롬프트
#
# * 너는 데이터 분석가야.
# * 선택한 셀에서 읽어 온 데이터 프레임을 사용하여 그래프를 그리려고 해.
# * 내가 가진 데이터 컬럼은 다음과 같아:
# - date, steps, sleep_hours, study_time, score
# * 질문: "공부 시간시간과 점수의 관계"를 보고 싶어.
# 어떤 그래프가 좋고, 왜 그런지 설명해줘.
# 그리고 Matplotlib 코드 예시를 줘.

# %% [markdown]
# ## 자주 발생하는 오류
#
# - 그래프가 안 뜸: `plt.show()` 누락, 실행 환경 문제
# - 한글 깨짐: 폰트 설정 필요(환경별 상이)
# - 데이터 길이 불일치: x와 y 길이 확인
# - NaN 존재: 결측치 처리 후 시각화
# - 해결: 에러 메시지 + 데이터 `shape` 확인

# %% [markdown]
# ## With AI 2: 그래프 오류 디버깅(길이 불일치)
#
# 에러 메시지 예: `ValueError: x and y must have same first dimension`
#
# 아래는 **일부러 에러를 만드는 코드**입니다.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [10, 20]  # 길이가 다름!

try:
    plt.plot(x, y)
    plt.show()
except Exception as e:
    print('에러:', type(e).__name__, e)

# 길이 확인
print('len(x)=', len(x), 'len(y)=', len(y))

# %% [markdown]
# ## With AI 3: 결과 해석 문장 생성(복사해서 사용)
#
# 내가 만든 그래프를 설명문으로 쓰고 싶어.
# 아래 요약 통계를 참고해서 3문장으로 해석을 작성해줘.
# 조건:
# - 과장 금지(사실 기반)
# - 한 문장은 이상치/예외에 대한 언급 포함
# - 마지막 문장은 다음 분석 제안 1개

# %% [markdown]
# # seaborn 라이브러리
# * Seaborn은 파이썬에서 고급 시각화를 위한 라이브러리로, 보다 미적인 그래프 작성을 위한 기본 스타일과 색상 팔레트를 제공한다.
# * Matplotlib을 기반으로 구축되었으며, Pandas의 자료구조와도 밀접하게 통합되어 있다.
# * Pandas에서도 그래프 작성 기능을 제공하지만, Seaborn을 사용하면 더욱 다양한 그래프를 간결한 코드로 편리하게 작성할 수 있다.
# * Seaborn의 가장 큰 장점은 간결함으로, 비교적 짧은 코드만으로도 데이터 분석에 필요한 주요 그래프를 빠르게 생성할 수 있다.
# * Seaborn의 그래프 메서드는 Matplotlib이나 Pandas의 그래프 메서드와 유사하여 쉽게 배울 수 있다.

# %% [markdown]
# ### seaborn 데이터셋 사용하기

# %%
import seaborn as sns
import pandas as pd

# 사용 가능한 데이터셋 확인
sns.get_dataset_names()

# %%
df = sns.load_dataset("tips")
print(df.head())

# %%
df.info()

# %%
df.describe()

# %%
df['sex'].unique()

# %%
df['sex'].value_counts()

# %%
# 모든 범주형 변수의 고유값 개수
categorical_columns = df.select_dtypes(include=['category']).columns

for col in categorical_columns:
    print(f"{col}. {df[col].nunique()}개의 고유값")
    print(f"  값. {list(df[col].unique())}")
    print()

# %% [markdown]
# ### 데이터 분석을 위한 질문들
# * 음식값과 팁 사이에 상관관계가 있는가?
# * 성별에 따라 팁을 주는 패턴이 다른가?
# * 요일별로 매출이나 팁에 차이가 있는가?
# * 흡연 여부가 소비 패턴에 영향을 주는가?
# * 인원수가 많을 수록 팁을 더 많이 주는가?

# %% [markdown]
# ## (기본 산점도) 음식가격과 팁의 상관관계

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'])

# %% [markdown]
# ## 색상을 활용한 그룹별 분석

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'], hue=df['sex'])

# %% [markdown]
# ## (버블차트) 크기를 활용한 3차원 정보 표현

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'], hue=df['sex'], size=df['size'])

# %% [markdown]
# ## 다차원 시각화

# %%
# 4개 변수를 동시에 표현
sns.scatterplot(x=df['total_bill'], y=df['tip'],
                hue=df['sex'],      # 색상으로 성별 구분
                size=df['size'],    # 크기로 인원수 표현
                style=df['time'],   # 모양으로 시간대 구분
                alpha=0.7)          # 투명도 조절

# %% [markdown]
# ### (참고) 산점도 vs 막대그래프

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 42]
sns.scatterplot(x=x, y=y)

# %%
sns.barplot(x=x, y=y)

# %% [markdown]
# # 회귀선(regplot)

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

# %% [markdown]
# ## 기본 회귀선 그래프

# %%
sns.regplot(x=df['total_bill'], y=df['tip'])

# %% [markdown]
# ## 회귀선만 표시하기

# %%
sns.regplot(x=df['total_bill'], y=df['tip'], scatter = False)

# %% [markdown]
# ## 신뢰구간의 이해

# %%
sns.regplot(x=df['total_bill'], y=df['tip'], scatter = False, ci = None)

# %% [markdown]
# # 선그래프(lineplot)

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## 기본 선 그래프 생성

# %%
x= [1, 2, 3, 4, 5]
y= [10, 20, 25, 30, 42]
sns.lineplot(x=x, y=y)

# %% [markdown]
# ## tips 데이터를 활용한 선그래프 실습

# %%
df.head()

# %%
df = sns.load_dataset('tips')
sns.lineplot(x=df['size'], y=df['tip'])

# %% [markdown]
# -----
# <div class="alert alert-warning">
# [Tip] 신뢰구간의 변경
# </div>

# %%
print("min:{}, max:{}".format(min(df[df['size'] == 5]['tip']), max(df[df['size'] == 5]['tip'])))

# %%
sns.lineplot(x=df['size'], y=df['tip'], errorbar=('ci', 100))

# %%
sns.lineplot(x=df['size'], y=df['tip'], errorbar=None)

# %% [markdown]
# ----------

# %%
sns.lineplot(x=df['size'], y=df['tip'], hue=df['day'],  errorbar=None)

# %% [markdown]
# -----
# <div class="alert alert-warning">
# [Tip] hue 속성은 범주형(category) 변수를 지정해주세요!
# </div>

# %%
# hue 속성에 여러 개의 값이 포함된 변수를 지정한 경우
sns.lineplot(x=df['day'], y=df['total_bill'], hue=df['tip'],  errorbar=None)

# %% [markdown]
# # 막대그래프(barplot)

# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("tips")
df.head()

# %%
df['size'].unique()

# %% [markdown]
# ## tips 데이터를 활용한 막대그래프 생성

# %%
sns.barplot(x=df['size'], y=df['tip'])

# %% [markdown]
# ### 신뢰구간 제거

# %%
sns.barplot(x=df['size'], y=df['tip'], errorbar=None)

# %% [markdown]
# -----
# <div class="alert alert-warning">
# [Tip] 막대의 길이가 비슷한 경우
# </div>

# %%
sns.barplot(x=df['day'], y=df['tip'])

# %% [markdown]
# ------

# %% [markdown]
# ### countplot: 개수 세기 전용 막대그래프

# %%
sns.countplot(x=df['day'])

# %%
df['day'].value_counts()

# %% [markdown]
# ### 막대그래프의 변형 : pointplot

# %% [markdown]
# -----
# <div class="alert alert-warning">
# [Tip] pointplot
# </div>

# %%
sns.pointplot(x=df['day'], y=df['tip'])

# %% [markdown]
# # 박스플롯(boxplot), 바이올린 플롯(violinplot)

# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("tips")
df.head()

# %%
sns.boxplot(x=df['size'], y=df['tip'])

# %%
sns.violinplot(x=df['size'], y=df['tip'])

# %% [markdown]
# # 히스토그램(histplot)

# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("tips")
df.head()

# %% [markdown]
# ## 1. 기본 히스토그램 생성

# %%
sns.histplot(data=df['total_bill'])

# %% [markdown]
# ## 2. bins(구간)조정

# %%
sns.histplot(data=df['total_bill'], bins=5)

# %% [markdown]
# ## 3. KDE 활용

# %%
sns.histplot(data=df['total_bill'], kde=True)

# %% [markdown]
# # 분포 시각화를 위한 다른 방법

# %% [markdown]
# ## 1. KDE plot

# %%
sns.kdeplot(data=df['total_bill'])

# %% [markdown]
# ## 2. rug plot

# %%
sns.rugplot(data=df['total_bill'])

# %% [markdown]
# ## 3. 히스토그램 vs 카운트플롯

# %%
sns.histplot(data=df['day'])

# %%
sns.countplot(data=df['day'])

# %% [markdown]
# # 기본 히트맵 생성

# %%
pivot_df = df.pivot_table("tip", "day", "size", observed=True)
pivot_df

# %%
sns.heatmap(pivot_df)

# %% [markdown]
# # 히트맵 값 표시

# %%
sns.heatmap(pivot_df, annot=True)

# %% [markdown]
# # 색상 팔레트 커스터마이징

# %%
# 다양한 색상 팔레트
sns.heatmap(pivot_df, annot=True, cmap='Blues')
sns.heatmap(pivot_df, annot=True, cmap='Reds')
sns.heatmap(pivot_df, annot=True, cmap='viridis')
sns.heatmap(pivot_df, annot=True, cmap='coolwarm')

# %% [markdown]
# # 색상 범위 조정

# %%
# 색상 범위 고정
sns.heatmap(pivot_df, annot=True, vmin=0, vmax=6)

# %%
# 중심값 설정
sns.heatmap(pivot_df, annot=True, center=3)

# %% [markdown]
# # 색상바와 격자 설정

# %%
# 색상바 제거
sns.heatmap(pivot_df, annot=True, cbar=False)

# 격자선 추가
sns.heatmap(pivot_df, annot=True, linewidths=0.5, linecolor='white')

# 격자 색상 변경
sns.heatmap(pivot_df, annot=True, linewidths=1, linecolor='black')

# %% [markdown]
# # 상관관계 히트맵

# %%
import numpy as np
import matplotlib.pyplot as plt

# 숫자형 변수들의 상관관계
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

# 상관관계 히트맵
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix,
            annot=True,           # 값 표시
            cmap='RdBu_r',       # 빨강-파랑 역순
            center=0,            # 0을 중심으로
            square=True,         # 정사각형 셀
            fmt='.2f')           # 소수점 2자리

# %%
# 상삼각형만 표시 (중복 제거)
import numpy as np

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix,
            mask=mask,
            annot=True,
            cmap='RdBu_r',
            center=0)

# %%
# 요일과 시간대별 평균 계산서
time_day_pivot = df.pivot_table('total_bill', 'day', 'time')

plt.figure(figsize=(8, 6))
sns.heatmap(time_day_pivot,
            annot=True,
            fmt='.1f',
            cmap='YlOrRd')

# %%
# 여러 지표를 동시에 표시
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# 평균 팁
tip_pivot = df.pivot_table('tip', 'day', 'size')
sns.heatmap(tip_pivot, annot=True, ax=axes[0], cmap='Blues')
axes[0].set_title('평균 팁')

# 평균 계산서
bill_pivot = df.pivot_table('total_bill', 'day', 'size')
sns.heatmap(bill_pivot, annot=True, ax=axes[1], cmap='Greens')
axes[1].set_title('평균 계산서')

# 방문 횟수
count_pivot = df.pivot_table('tip', 'day', 'size', aggfunc='count')
sns.heatmap(count_pivot, annot=True, ax=axes[2], cmap='Oranges')
axes[2].set_title('방문 횟수')

plt.tight_layout()

# %%
# 카테고리 순서 지정
day_order = ['Thur', 'Fri', 'Sat', 'Sun']
size_order = [1, 2, 3, 4, 5, 6]

# 순서가 지정된 피봇 테이블
pivot_ordered = df.pivot_table('tip', 'day', 'size')
pivot_ordered = pivot_ordered.reindex(day_order)
pivot_ordered = pivot_ordered.reindex(columns=size_order)

sns.heatmap(pivot_ordered, annot=True)
