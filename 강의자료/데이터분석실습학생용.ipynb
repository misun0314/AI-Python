# %% [markdown]
# <a href="https://colab.research.google.com/github/misun0314/AI-Python/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EC%8B%A4%EC%8A%B5%ED%95%99%EC%83%9D%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install -y fonts-nanum* -qq
# !rm ~/.cache/matplotlib -rf

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %% [markdown]
# * 기본 폰트로 한글 폰트 전역 설정

# %%
fontpath="/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
font=fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ##seaborn에서 제공하는 titanic 데이터셋을 사용하여 다음 순서를 따라 선실별 생존율을 분석하시오.
# 1. titanic 데이터셋을 df에 저장하고, 다음 조건에 따라 값을 변경하시오.
#    * [조건]
#      *생존 여부(survived): 0은 ‘사망’, 1은 ‘생존’으로 값을 변경한다.
#      * 선실(pclass): 1은 ‘1등실’, 2는 ‘2등실’, 3은 ‘3등실’로 값을 변경한다.
# 2. 선실별 인원수를 막대그래프로 나타내되, 각 막대는 사망 인원과 생존 인원을 구분하여 표시하시오.
# 3. 선실별 생존 인원을 모자이크 플롯으로 나타내되, x축에는 선실(pclass)을, y축에는 생존 여부(survived)를 표시하시오.
# 4. 선실별 생존 인원을 트리맵으로 나타내시오. 단, 선실 타일 안에 생존 여부 타일이 포함되도록 그래프를 작성한다.

# %%
# 사용 가능한 데이터셋 확인
sns.get_dataset_names()
